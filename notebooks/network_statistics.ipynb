# %% [markdown]
# <div align="center" style="width: 100%; margin: 50px 0 100px;">
#     <div style="background-color: #2F3C4A; border: 4px dotted #2F3C4A;">
#         <h1 style="font-family: courier; font-size: 3.5em; color:#FFFFFF;">Network Statistics</h1>
#     </div>
# </div>

# %%
from tabulate import tabulate
import networkx as nx
import utils as utl
import json
import matplotlib.pyplot as plt

# %%
config = utl.EnumResult()

def print_graph(name, G):
    print(f'\n{name}\tNodes: {G.number_of_nodes()}\tEdges: {G.number_of_edges()}')
    
def graph_resume(G):
    GN = utl.network_statistics(G)
    print('\n\n'+json.dumps(GN, indent=2)+'\n')
    
    if GN['number_of_edges'] < 100000:
        plt.figure(figsize=(22,18))
        pos = nx.spring_layout(G)
        nx.draw_networkx_nodes(G, pos, node_color="b", alpha=0.3)
        nx.draw_networkx_edges(G, pos, node_size=500)
        plt.axis('off')
        plt.show()

# %% [markdown]
# <div align="center" style="width: 100%; margin: 20px 0 100px;">
#     <div style="background-color: #ffffcc; width: 80%; border: 3px dotted #cc2222;">
#         <h4 style="font-family: courier; font-size: 2em;">BIG NETWORKS</h4>
#     </div>
# </div>
#
# ### Facebook EGO

# %%
# %%time

#G = nx.read_edgelist("data/facebook_combined.txt.gz", nodetype=int)
G = nx.read_gexf("facebook_combined.gexf")
graph_resume(G)
# Out:
# Métricas iniciais da rede...
#
# Name:
# Type: Graph
# Number of nodes: 4039
# Number of edges: 88234
# Average degree:  43.6910
#
#                                  Process    Time
# ========================================    =========================
#                                  Density     0.0
#                                 Diameter     80.9350917339325
#                                   Radius     78.62561368942261
#                           Average Degree     0.0
#
#
# {
#   "number_of_nodes": 4039,
#   "number_of_edges": 88234,
#   "density": 0.01082,
#   "diameter": 8,
#   "radius": 4,
#   "average_degree": 43.69101,
#   "is_connected": true,
#   "number_connected_components": 1
# }
# Wall time: 4min 1s

# %% [markdown]
# ### Facebook Simmons81

# %%
# %%time

G = nx.read_gexf("socfb-Simmons81.gexf")
graph_resume(G)
# Out:
# Métricas iniciais da rede...
#
# Name:
# Type: Graph
# Number of nodes: 1510
# Number of edges: 32984
# Average degree:  43.6874
#
#                                  Process    Time
# ========================================    =========================
#                                  Density     0.0009992122650146484
#                                 Diameter     7.09886622428894
#                                   Radius     6.91812539100647
#                           Average Degree     0.0
#
#
# {
#   "number_of_nodes": 1510,
#   "number_of_edges": 32984,
#   "density": 0.02895,
#   "diameter": 7,
#   "radius": 4,
#   "average_degree": 43.68742,
#   "is_connected": true,
#   "number_connected_components": 1
# }
# Wall time: 26.5 s

# %% [markdown]
# ### Facebook Bowdoin47

# %%
# %%time

G = nx.read_gexf("socfb-Bowdoin47.gexf")
graph_resume(G)
# Out:
# Métricas iniciais da rede...
#
# Name:
# Type: Graph
# Number of nodes: 2250
# Number of edges: 84386
# Average degree:  75.0098
#
#                                  Process    Time
# ========================================    =========================
#                                  Density     0.001001119613647461
#                                 Diameter     40.06784653663635
#                                   Radius     38.49922275543213
#                           Average Degree     0.0009999275207519531
#
#
# {
#   "number_of_nodes": 2250,
#   "number_of_edges": 84386,
#   "density": 0.03335,
#   "diameter": 6,
#   "radius": 4,
#   "average_degree": 75.00978,
#   "is_connected": true,
#   "number_connected_components": 1
# }
# Wall time: 1min 44s

# %% [markdown]
# ### Facebook Haverford76

# %%
# %%time

G = nx.read_gexf("socfb-Haverford76.gexf")
graph_resume(G)
# Out:
# Métricas iniciais da rede...
#
# Name:
# Type: Graph
# Number of nodes: 1446
# Number of edges: 59589
# Average degree:  82.4191
#
#                                  Process    Time
# ========================================    =========================
#                                  Density     0.0
#                                 Diameter     13.21064567565918
#                                   Radius     13.461409091949463
#                           Average Degree     0.0
#
#
# {
#   "number_of_nodes": 1446,
#   "number_of_edges": 59589,
#   "density": 0.05704,
#   "diameter": 6,
#   "radius": 4,
#   "average_degree": 82.41909,
#   "is_connected": true,
#   "number_connected_components": 1
# }
# Wall time: 40.3 s

# %% [markdown]
# ### Twitter EGO

# %%
# %%time

G = nx.read_adjlist("../data/twitter_combined.txt.gz", create_using=nx.DiGraph(), nodetype=int)
graph_resume(G)

# %% [markdown]
# ### Twitter SOC

# %%
# %%time

G = nx.read_adjlist("../data/soc-twitter-follows.mtx", create_using=nx.DiGraph(), nodetype=int)
graph_resume(G)

# %% [markdown]
# ### Youtube SOC

# %%
# %%time

G = nx.read_adjlist("../data/soc-youtube.mtx", create_using=nx.DiGraph(), nodetype=int)
graph_resume(G)

# %% [markdown]
# ### soc_academia

# %%
# %%time

G = nx.read_adjlist("../data/soc-academia.edges", create_using=nx.DiGraph(), nodetype=int)
graph_resume(G)

# %% [markdown]
# ### wiki-Vote

# %%
# %%time

G = nx.read_gexf("wiki-Vote.gexf")
graph_resume(G)
# Out:
# Métricas iniciais da rede...
#
# Name:
# Type: Graph
# Number of nodes: 7066
# Number of edges: 100736
# Average degree:  28.5129
#
#                                  Process    Time
# ========================================    =========================
#                                  Density     0.0029997825622558594
#                                 Diameter     200.18988013267517
#                                   Radius     190.02265191078186
#                           Average Degree     0.0
#
#
# {
#   "number_of_nodes": 7066,
#   "number_of_edges": 100736,
#   "density": 0.00404,
#   "diameter": 7,
#   "radius": 4,
#   "average_degree": 28.51288,
#   "is_connected": true,
#   "number_connected_components": 1
# }
#
# Wall time: 6min 32s

# %% [markdown]
# ### socfb-OR

# %%
# %%time

G = nx.read_adjlist("../data/socfb-OR.mtx", create_using=nx.DiGraph(), nodetype=int)
graph_resume(G)

# %% [markdown]
# ### soc-Slashdot0902

# %%
# %%time

G = nx.read_adjlist("../data/soc-Slashdot0902.txt.gz", create_using=nx.DiGraph(), nodetype=int)
graph_resume(G)

# %% [markdown]
# ### socfb-Rutgers89

# %%
# %%time

#G = nx.read_adjlist("../data/socfb-Rutgers89.mtx", create_using=nx.DiGraph(), nodetype=int)
G = nx.read_gexf("socfb-Rutgers89.gexf")
graph_resume(G)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <decorator-gen-813> in read_gexf(path, node_type, relabel, version)
#
# c:\users\spock\appdata\local\programs\python\python38\lib\site-packages\networkx\utils\decorators.py in _open_file(func_to_be_decorated, *args, **kwargs)
#     237         # Finally, we call the original function, making sure to close the fobj
#     238         try:
# --> 239             result = func_to_be_decorated(*new_args, **kwargs)
#     240         finally:
#     241             if close_fobj:
#
# c:\users\spock\appdata\local\programs\python\python38\lib\site-packages\networkx\readwrite\gexf.py in read_gexf(path, node_type, relabel, version)
#     167         G = relabel_gexf_graph(reader(path))
#     168     else:
# --> 169         G = reader(path)
#     170     return G
#     171
#
# KeyboardInterrupt:

# %% [markdown]
# ### socfb-UF21

# %%
# %%time

G = nx.read_adjlist("../data/socfb-UF21.mtx", create_using=nx.DiGraph(), nodetype=int)
graph_resume(G)

# %% [markdown]
# <div align="center" style="width: 100%; margin: 20px 0 100px;">
#     <div style="background-color: #ffffcc; width: 80%; border: 3px dotted #cc2222;">
#         <h4 style="font-family: courier; font-size: 2em;">TINY NETWORKS</h4>
#     </div>
# </div>

# %%
# %%time

G = nx.read_gexf('fb1.gexf')
graph_resume(G)
# Out:
# Métricas iniciais da rede...
#
# Name:
# Type: Graph
# Number of nodes: 168
# Number of edges: 168
# Average degree:   2.0000
#
#                                  Process    Time
# ========================================    =========================
#                                  Density     0.0
#                                 Diameter     0.009003639221191406
#                                   Radius     0.008001565933227539
#                           Average Degree     0.0009999275207519531
#
#
# {
#   "number_of_nodes": 168,
#   "number_of_edges": 168,
#   "density": 0.01198,
#   "diameter": 2,
#   "radius": 1,
#   "average_degree": 2.0,
#   "is_connected": true,
#   "number_connected_components": 1
# }
# Wall time: 469 ms

# %%
# %%time

G = nx.read_gexf('fb2.gexf')
graph_resume(G)
# Out:
# Métricas iniciais da rede...
#
# Name:
# Type: Graph
# Number of nodes: 324
# Number of edges: 2514
# Average degree:  15.5185
#
#                                  Process    Time
# ========================================    =========================
#                                  Density     0.0
#                                 Diameter     0.1492173671722412
#                                   Radius     0.17186760902404785
#                           Average Degree     0.0
#
#
# {
#   "number_of_nodes": 324,
#   "number_of_edges": 2514,
#   "density": 0.04804,
#   "diameter": 11,
#   "radius": 6,
#   "average_degree": 15.51852,
#   "is_connected": true,
#   "number_connected_components": 1
# }
# Wall time: 955 ms

# %%
# %%time

G = nx.read_gexf('fb3.gexf')
graph_resume(G)
# Out:
# Métricas iniciais da rede...
#
# Name:
# Type: Graph
# Number of nodes: 224
# Number of edges: 224
# Average degree:   2.0000
#
#                                  Process    Time
# ========================================    =========================
#                                  Density     0.0
#                                 Diameter     0.01599717140197754
#                                   Radius     0.015000104904174805
#                           Average Degree     0.0
#
#
# {
#   "number_of_nodes": 224,
#   "number_of_edges": 224,
#   "density": 0.00897,
#   "diameter": 2,
#   "radius": 1,
#   "average_degree": 2.0,
#   "is_connected": true,
#   "number_connected_components": 1
# }
# Wall time: 385 ms

# %%
# %%time

G = nx.read_gexf('fb4.gexf')
graph_resume(G)
# Out:
# Métricas iniciais da rede...
#
# Name:
# Type: Graph
# Number of nodes: 59
# Number of edges: 100
# Average degree:   3.3898
#
#                                  Process    Time
# ========================================    =========================
#                                  Density     0.0
#                                 Diameter     0.003996849060058594
#                                   Radius     0.0020020008087158203
#                           Average Degree     0.0
#
#
# {
#   "number_of_nodes": 59,
#   "number_of_edges": 100,
#   "density": 0.05845,
#   "diameter": 3,
#   "radius": 2,
#   "average_degree": 3.38983,
#   "is_connected": true,
#   "number_connected_components": 1
# }
# Wall time: 200 ms

# %% [markdown]
# <hr style="height:2em; border: 3px dashed #999; margin: 30px 0 20px;" />
